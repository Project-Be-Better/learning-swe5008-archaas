# %% [markdown]
# ##### Hello World + LangGraph Workspace
#
# This notebook demonstrates basic Python execution and verifies that the virtual environment is active.

# %%
print("Hello World from LangGraph!")
# Out:
# Hello World from LangGraph!

# %%
# Create a variable and display it
message = "This is my first LangGraph workspace!"
print(message)
# Out:
# This is my first LangGraph workspace!

# %%
# Verify virtual environment is active
import sys

print("Python executable:", sys.executable)
print("Python prefix:", sys.prefix)
print("Virtual env active:", sys.prefix != sys.base_prefix)
# Out:
# Python executable: d:\learning-projects\learning-swe5008-archaas\.venv\Scripts\python.exe
# Python prefix: d:\learning-projects\learning-swe5008-archaas\.venv
# Virtual env active: True

# %%
# Verify LangGraph is installed from venv
import langgraph
from importlib.metadata import version

print("LangGraph version:", version("langgraph"))
print("LangGraph location:", langgraph.__file__)
# Out:
# LangGraph version: 1.0.10
# LangGraph location: None
